# %% [markdown]
# ## Python Assignment 2: Data Structures - List, Dictionary, Set & Conditional Statements

# %% [markdown]
# ## LIST(Creation,modification and access)

# %%
age_list=[34,35,36,37,38]
print(age_list)
# Out:
# [34, 35, 36, 37, 38]

# %%
name_list=["suresh","santhosh","amal","remya","hema"]
print(name_list)
# Out:
# ['suresh', 'santhosh', 'amal', 'remya', 'hema']

# %%
name_list.append("yazhini")
print(name_list)
# Out:
# ['suresh', 'santhosh', 'amal', 'remya', 'hema', 'yazhini']

# %%
print(age_list[2])
# Out:
# 36

# %%
age_list.insert(2,30)
print(age_list[2])
# Out:
# 30

# %%
print(name_list)
name_list.remove("yazhini")
print(name_list)
# Out:
# ['suresh', 'santhosh', 'amal', 'remya', 'hema', 'yazhini']
# ['suresh', 'santhosh', 'amal', 'remya', 'hema']

# %%
print(age_list)
age_list.pop()
print(age_list)
# Out:
# [34, 35, 30, 36, 37, 38]
# [34, 35, 30, 36, 37]

# %%
print(age_list)
age_list.extend([29,30,26])
print(age_list)
# Out:
# [34, 35, 30, 36, 37]
# [34, 35, 30, 36, 37, 29, 30, 26]

# %%
age_list.sort(reverse=True)
print(age_list)
# Out:
# [37, 36, 35, 34, 30, 30, 29, 26]

# %%
max_age = max(age_list)
print("Max age:", max_age)
# Out:
# Max age: 37

# %%
min_age = min(age_list)
print("min age:",min_age)
# Out:
# min age: 26

# %%
total_sum =sum(age_list)
print("total sum of age:",total_sum)
# Out:
# total sum of age: 257

# %%
print(name_list)
# Out:
# ['suresh', 'santhosh', 'amal', 'remya', 'hema']

# %%
print(name_list[0])
# Out:
# suresh

# %%
print(name_list[-1])
# Out:
# hema

# %%
print(name_list[2:5])
# Out:
# ['amal', 'remya', 'hema']

# %%
print(name_list[::-1])
# Out:
# ['hema', 'remya', 'amal', 'santhosh', 'suresh']

# %% [markdown]
# ## DICTIONARY(Creation,modification and access)

# %%
student_marks={"robin":55, "nixon":66,"ram":64 ,"babu":45, "nancy":71}
print(student_marks)
# Out:
# {'robin': 55, 'nixon': 66, 'ram': 64, 'babu': 45, 'nancy': 71}

# %%
print(student_marks["robin"])
# Out:
# 55

# %%
print(student_marks)
student_marks["Janani"] = 80
print(student_marks)
# Out:
# {'robin': 55, 'nixon': 66, 'ram': 64, 'babu': 45, 'nancy': 71}
# {'robin': 55, 'nixon': 66, 'ram': 64, 'babu': 45, 'nancy': 71, 'Janani': 80}

# %%
student_marks.update({"ram":82})
print(student_marks)
# Out:
# {'robin': 55, 'nixon': 66, 'ram': 82, 'babu': 45, 'nancy': 71, 'Janani': 80}

# %%
student_marks={"robin":55, "nixon":66,"ram":82 ,"babu":45, "nancy":71,"Janani":80}
print(student_marks)
# Out:
# {'robin': 55, 'nixon': 66, 'ram': 82, 'babu': 45, 'nancy': 71, 'Janani': 80}

# %%
print("All Keys:")
print(student_marks.keys())
# Out:
# All Keys:
# dict_keys(['robin', 'nixon', 'ram', 'babu', 'nancy', 'Janani'])

# %%
print("\nAll Values:")
print(student_marks.values())
# Out:
# All Values:
# dict_values([55, 66, 82, 45, 71, 80])

# %%
print("\nAll Key-Value Pairs:")
print(student_marks.items())
# Out:
# All Key-Value Pairs:
# dict_items([('robin', 55), ('nixon', 66), ('ram', 82), ('babu', 45), ('nancy', 71), ('Janani', 80)])

# %% [markdown]
# ## sets(operations)

# %%
my_set={'a','e','i','o','u','a','a','i'}
print(my_set)
# Out:
# {'o', 'a', 'i', 'u', 'e'}

# %% [markdown]
# set operations is not ordered and eliminate the duplicate(unique). a and i is entered 2 times set operation eliminate 1  and other kept.

# %%
my_set[4] = 's'
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 my_set[4] = 's'
#       2 print(my_set)
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# set elements immutable and not using indexing.

# %%
set1={1,3,5,7,9}
set2={2,3,5,8,10}
set_union = set1.union(set2)
print("Union:", set_union)
set_intersection = set1.intersection(set2)
print("Intersection:", set_intersection)
# Out:
# Union: {1, 2, 3, 5, 7, 8, 9, 10}
# Intersection: {3, 5}

# %% [markdown]
# ## operators and conditional statements(if,elif,else)

# %%
score = float(input("Enter your score (0 to 10): "))
# Out:
# Enter your score (0 to 10):  8

# %%
if score < 0 or score > 10:
    print("Invalid Input! Please enter a score between 0 and 10.")
else:
    if score > 7:
        print("Above Average: Outstanding work! You have mastered this concept.")
    elif 4 <= score <= 7:
        print("Average: Good effort! Keep practicing, there's room for growth.")
    else:
        print("Below Average: Need to improve your performance. Consistent practice will lead to better results.")
# Out:
# Above Average: Outstanding work! You have mastered this concept.
